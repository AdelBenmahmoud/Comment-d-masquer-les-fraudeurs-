# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
x_train=pd.read_csv('X_train_G3tdtEn.csv',low_memory=False )

# %%
x_train.rename(index = {0: '0'}, inplace = True)

# %%
x_train.head()
# Out:
#       ID                             item1                             item2  \
# 0  85517                         COMPUTERS                               NaN
# 1  51113  COMPUTER PERIPHERALS ACCESSORIES                               NaN
# 2  83008           TELEVISIONS HOME CINEMA                               NaN
# 3  78712                         COMPUTERS  COMPUTER PERIPHERALS ACCESSORIES
# 4  77846           TELEVISIONS HOME CINEMA                               NaN
#
#   item3 item4 item5 item6 item7 item8 item9 item10 item11 item12 item13  \
# 0   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN    NaN    NaN    NaN
# 1   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN    NaN    NaN    NaN
# 2   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN    NaN    NaN    NaN
# 3   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN    NaN    NaN    NaN
# 4   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN    NaN    NaN    NaN
#
#   item14 item15 item16 item17 item18 item19 item20 item21 item22 item23  \
# 0    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 3    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 4    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#   item24  cash_price1  cash_price2  cash_price3  cash_price4  cash_price5  \
# 0    NaN        889.0          NaN          NaN          NaN          NaN
# 1    NaN        409.0          NaN          NaN          NaN          NaN
# 2    NaN       1399.0          NaN          NaN          NaN          NaN
# 3    NaN        689.0        119.0          NaN          NaN          NaN
# 4    NaN       1199.0          NaN          NaN          NaN          NaN
#
#    cash_price6  cash_price7  cash_price8  cash_price9  cash_price10  \
# 0          NaN          NaN          NaN          NaN           NaN
# 1          NaN          NaN          NaN          NaN           NaN
# 2          NaN          NaN          NaN          NaN           NaN
# 3          NaN          NaN          NaN          NaN           NaN
# 4          NaN          NaN          NaN          NaN           NaN
#
#    cash_price11  cash_price12  cash_price13  cash_price14  cash_price15  \
# 0           NaN           NaN           NaN           NaN           NaN
# 1           NaN           NaN           NaN           NaN           NaN
# 2           NaN           NaN           NaN           NaN           NaN
# 3           NaN           NaN           NaN           NaN           NaN
# 4           NaN           NaN           NaN           NaN           NaN
#
#    cash_price16  cash_price17  cash_price18  cash_price19  cash_price20  \
# 0           NaN           NaN           NaN           NaN           NaN
# 1           NaN           NaN           NaN           NaN           NaN
# 2           NaN           NaN           NaN           NaN           NaN
# 3           NaN           NaN           NaN           NaN           NaN
# 4           NaN           NaN           NaN           NaN           NaN
#
#    cash_price21  cash_price22  cash_price23  cash_price24    make1  make2  \
# 0           NaN           NaN           NaN           NaN    APPLE    NaN
# 1           NaN           NaN           NaN           NaN    APPLE    NaN
# 2           NaN           NaN           NaN           NaN  SAMSUNG    NaN
# 3           NaN           NaN           NaN           NaN    APPLE  APPLE
# 4           NaN           NaN           NaN           NaN     SONY    NaN
#
#   make3 make4 make5 make6 make7 make8 make9 make10 make11 make12 make13  \
# 0   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN    NaN    NaN    NaN
# 1   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN    NaN    NaN    NaN
# 2   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN    NaN    NaN    NaN
# 3   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN    NaN    NaN    NaN
# 4   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN    NaN    NaN    NaN
#
#   make14 make15 make16 make17 make18 make19 make20 make21 make22 make23  \
# 0    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 3    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 4    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#   make24                                             model1  \
# 0    NaN  2020 APPLE MACBOOK AIR 13 3 RETINA DISPLAY M1 ...
# 1    NaN  APPLE WATCH SERIES 6 GPS 44MM SPACE GREY ALUMI...
# 2    NaN  SAMSUNG QE75Q70A 2021 QLED HDR 4K ULTRA HD SMA...
# 3    NaN  2020 APPLE IPAD AIR 10 9 A14 BIONIC PROCESSOR IOS
# 4    NaN  SONY BRAVIA KE48A9 2020 OLED HDR 4K ULTRA HD S...
#
#                                          model2 model3 model4 model5 model6  \
# 0                                           NaN    NaN    NaN    NaN    NaN
# 1                                           NaN    NaN    NaN    NaN    NaN
# 2                                           NaN    NaN    NaN    NaN    NaN
# 3  APPLE PENCIL 2ND GENERATION 2018 MATTE WHITE    NaN    NaN    NaN    NaN
# 4                                           NaN    NaN    NaN    NaN    NaN
#
#   model7 model8 model9 model10 model11 model12 model13 model14 model15  \
# 0    NaN    NaN    NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1    NaN    NaN    NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2    NaN    NaN    NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3    NaN    NaN    NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4    NaN    NaN    NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#   model16 model17 model18 model19 model20 model21 model22 model23 model24  \
# 0     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#   goods_code1 goods_code2 goods_code3 goods_code4 goods_code5 goods_code6  \
# 0   239246776         NaN         NaN         NaN         NaN         NaN
# 1   239001518         NaN         NaN         NaN         NaN         NaN
# 2   239842093         NaN         NaN         NaN         NaN         NaN
# 3   239001422   237841896         NaN         NaN         NaN         NaN
# 4   239952954         NaN         NaN         NaN         NaN         NaN
#
#   goods_code7 goods_code8 goods_code9 goods_code10 goods_code11 goods_code12  \
# 0         NaN         NaN         NaN          NaN          NaN          NaN
# 1         NaN         NaN         NaN          NaN          NaN          NaN
# 2         NaN         NaN         NaN          NaN          NaN          NaN
# 3         NaN         NaN         NaN          NaN          NaN          NaN
# 4         NaN         NaN         NaN          NaN          NaN          NaN
#
#   goods_code13 goods_code14 goods_code15 goods_code16 goods_code17  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
#   goods_code18 goods_code19 goods_code20 goods_code21 goods_code22  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
#   goods_code23 goods_code24  Nbr_of_prod_purchas1  Nbr_of_prod_purchas2  \
# 0          NaN          NaN                   1.0                   NaN
# 1          NaN          NaN                   1.0                   NaN
# 2          NaN          NaN                   1.0                   NaN
# 3          NaN          NaN                   1.0                   1.0
# 4          NaN          NaN                   1.0                   NaN
#
#    Nbr_of_prod_purchas3  Nbr_of_prod_purchas4  Nbr_of_prod_purchas5  \
# 0                   NaN                   NaN                   NaN
# 1                   NaN                   NaN                   NaN
# 2                   NaN                   NaN                   NaN
# 3                   NaN                   NaN                   NaN
# 4                   NaN                   NaN                   NaN
#
#    Nbr_of_prod_purchas6  Nbr_of_prod_purchas7  Nbr_of_prod_purchas8  \
# 0                   NaN                   NaN                   NaN
# 1                   NaN                   NaN                   NaN
# 2                   NaN                   NaN                   NaN
# 3                   NaN                   NaN                   NaN
# 4                   NaN                   NaN                   NaN
#
#    Nbr_of_prod_purchas9  Nbr_of_prod_purchas10  Nbr_of_prod_purchas11  \
# 0                   NaN                    NaN                    NaN
# 1                   NaN                    NaN                    NaN
# 2                   NaN                    NaN                    NaN
# 3                   NaN                    NaN                    NaN
# 4                   NaN                    NaN                    NaN
#
#    Nbr_of_prod_purchas12  Nbr_of_prod_purchas13  Nbr_of_prod_purchas14  \
# 0                    NaN                    NaN                    NaN
# 1                    NaN                    NaN                    NaN
# 2                    NaN                    NaN                    NaN
# 3                    NaN                    NaN                    NaN
# 4                    NaN                    NaN                    NaN
#
#    Nbr_of_prod_purchas15  Nbr_of_prod_purchas16  Nbr_of_prod_purchas17  \
# 0                    NaN                    NaN                    NaN
# 1                    NaN                    NaN                    NaN
# 2                    NaN                    NaN                    NaN
# 3                    NaN                    NaN                    NaN
# 4                    NaN                    NaN                    NaN
#
#    Nbr_of_prod_purchas18  Nbr_of_prod_purchas19  Nbr_of_prod_purchas20  \
# 0                    NaN                    NaN                    NaN
# 1                    NaN                    NaN                    NaN
# 2                    NaN                    NaN                    NaN
# 3                    NaN                    NaN                    NaN
# 4                    NaN                    NaN                    NaN
#
#    Nbr_of_prod_purchas21  Nbr_of_prod_purchas22  Nbr_of_prod_purchas23  \
# 0                    NaN                    NaN                    NaN
# 1                    NaN                    NaN                    NaN
# 2                    NaN                    NaN                    NaN
# 3                    NaN                    NaN                    NaN
# 4                    NaN                    NaN                    NaN
#
#    Nbr_of_prod_purchas24  Nb_of_items
# 0                    NaN          1.0
# 1                    NaN          1.0
# 2                    NaN          1.0
# 3                    NaN          2.0
# 4                    NaN          1.0

# %%
xtrain_copy = x_train.copy()

# %%
xtrain_copy.head()
# Out:
#                                   item1                             item2  \
# ID
# 85517                         COMPUTERS                               NaN
# 51113  COMPUTER PERIPHERALS ACCESSORIES                               NaN
# 83008           TELEVISIONS HOME CINEMA                               NaN
# 78712                         COMPUTERS  COMPUTER PERIPHERALS ACCESSORIES
# 77846           TELEVISIONS HOME CINEMA                               NaN
#
#       item3 item4 item5 item6 item7 item8 item9 item10 item11 item12 item13  \
# ID
# 85517   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN    NaN    NaN    NaN
# 51113   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN    NaN    NaN    NaN
# 83008   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN    NaN    NaN    NaN
# 78712   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN    NaN    NaN    NaN
# 77846   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN    NaN    NaN    NaN
#
#       item14 item15 item16 item17 item18 item19 item20 item21 item22 item23  \
# ID
# 85517    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 51113    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 83008    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 78712    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 77846    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#       item24  cash_price1  cash_price2  cash_price3  cash_price4  cash_price5  \
# ID
# 85517    NaN        889.0          NaN          NaN          NaN          NaN
# 51113    NaN        409.0          NaN          NaN          NaN          NaN
# 83008    NaN       1399.0          NaN          NaN          NaN          NaN
# 78712    NaN        689.0        119.0          NaN          NaN          NaN
# 77846    NaN       1199.0          NaN          NaN          NaN          NaN
#
#        cash_price6  cash_price7  cash_price8  cash_price9  cash_price10  \
# ID
# 85517          NaN          NaN          NaN          NaN           NaN
# 51113          NaN          NaN          NaN          NaN           NaN
# 83008          NaN          NaN          NaN          NaN           NaN
# 78712          NaN          NaN          NaN          NaN           NaN
# 77846          NaN          NaN          NaN          NaN           NaN
#
#        cash_price11  cash_price12  cash_price13  cash_price14  cash_price15  \
# ID
# 85517           NaN           NaN           NaN           NaN           NaN
# 51113           NaN           NaN           NaN           NaN           NaN
# 83008           NaN           NaN           NaN           NaN           NaN
# 78712           NaN           NaN           NaN           NaN           NaN
# 77846           NaN           NaN           NaN           NaN           NaN
#
#        cash_price16  cash_price17  cash_price18  cash_price19  cash_price20  \
# ID
# 85517           NaN           NaN           NaN           NaN           NaN
# 51113           NaN           NaN           NaN           NaN           NaN
# 83008           NaN           NaN           NaN           NaN           NaN
# 78712           NaN           NaN           NaN           NaN           NaN
# 77846           NaN           NaN           NaN           NaN           NaN
#
#        cash_price21  cash_price22  cash_price23  cash_price24    make1  make2  \
# ID
# 85517           NaN           NaN           NaN           NaN    APPLE    NaN
# 51113           NaN           NaN           NaN           NaN    APPLE    NaN
# 83008           NaN           NaN           NaN           NaN  SAMSUNG    NaN
# 78712           NaN           NaN           NaN           NaN    APPLE  APPLE
# 77846           NaN           NaN           NaN           NaN     SONY    NaN
#
#       make3 make4 make5 make6 make7 make8 make9 make10 make11 make12 make13  \
# ID
# 85517   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN    NaN    NaN    NaN
# 51113   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN    NaN    NaN    NaN
# 83008   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN    NaN    NaN    NaN
# 78712   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN    NaN    NaN    NaN
# 77846   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN    NaN    NaN    NaN
#
#       make14 make15 make16 make17 make18 make19 make20 make21 make22 make23  \
# ID
# 85517    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 51113    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 83008    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 78712    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 77846    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#       make24                                             model1  \
# ID
# 85517    NaN  2020 APPLE MACBOOK AIR 13 3 RETINA DISPLAY M1 ...
# 51113    NaN  APPLE WATCH SERIES 6 GPS 44MM SPACE GREY ALUMI...
# 83008    NaN  SAMSUNG QE75Q70A 2021 QLED HDR 4K ULTRA HD SMA...
# 78712    NaN  2020 APPLE IPAD AIR 10 9 A14 BIONIC PROCESSOR IOS
# 77846    NaN  SONY BRAVIA KE48A9 2020 OLED HDR 4K ULTRA HD S...
#
#                                              model2 model3 model4 model5  \
# ID
# 85517                                           NaN    NaN    NaN    NaN
# 51113                                           NaN    NaN    NaN    NaN
# 83008                                           NaN    NaN    NaN    NaN
# 78712  APPLE PENCIL 2ND GENERATION 2018 MATTE WHITE    NaN    NaN    NaN
# 77846                                           NaN    NaN    NaN    NaN
#
#       model6 model7 model8 model9 model10 model11 model12 model13 model14  \
# ID
# 85517    NaN    NaN    NaN    NaN     NaN     NaN     NaN     NaN     NaN
# 51113    NaN    NaN    NaN    NaN     NaN     NaN     NaN     NaN     NaN
# 83008    NaN    NaN    NaN    NaN     NaN     NaN     NaN     NaN     NaN
# 78712    NaN    NaN    NaN    NaN     NaN     NaN     NaN     NaN     NaN
# 77846    NaN    NaN    NaN    NaN     NaN     NaN     NaN     NaN     NaN
#
#       model15 model16 model17 model18 model19 model20 model21 model22 model23  \
# ID
# 85517     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 51113     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 83008     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 78712     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 77846     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#       model24 goods_code1 goods_code2 goods_code3 goods_code4 goods_code5  \
# ID
# 85517     NaN   239246776         NaN         NaN         NaN         NaN
# 51113     NaN   239001518         NaN         NaN         NaN         NaN
# 83008     NaN   239842093         NaN         NaN         NaN         NaN
# 78712     NaN   239001422   237841896         NaN         NaN         NaN
# 77846     NaN   239952954         NaN         NaN         NaN         NaN
#
#       goods_code6 goods_code7 goods_code8 goods_code9 goods_code10  \
# ID
# 85517         NaN         NaN         NaN         NaN          NaN
# 51113         NaN         NaN         NaN         NaN          NaN
# 83008         NaN         NaN         NaN         NaN          NaN
# 78712         NaN         NaN         NaN         NaN          NaN
# 77846         NaN         NaN         NaN         NaN          NaN
#
#       goods_code11 goods_code12 goods_code13 goods_code14 goods_code15  \
# ID
# 85517          NaN          NaN          NaN          NaN          NaN
# 51113          NaN          NaN          NaN          NaN          NaN
# 83008          NaN          NaN          NaN          NaN          NaN
# 78712          NaN          NaN          NaN          NaN          NaN
# 77846          NaN          NaN          NaN          NaN          NaN
#
#       goods_code16 goods_code17 goods_code18 goods_code19 goods_code20  \
# ID
# 85517          NaN          NaN          NaN          NaN          NaN
# 51113          NaN          NaN          NaN          NaN          NaN
# 83008          NaN          NaN          NaN          NaN          NaN
# 78712          NaN          NaN          NaN          NaN          NaN
# 77846          NaN          NaN          NaN          NaN          NaN
#
#       goods_code21 goods_code22 goods_code23 goods_code24  \
# ID
# 85517          NaN          NaN          NaN          NaN
# 51113          NaN          NaN          NaN          NaN
# 83008          NaN          NaN          NaN          NaN
# 78712          NaN          NaN          NaN          NaN
# 77846          NaN          NaN          NaN          NaN
#
#        Nbr_of_prod_purchas1  Nbr_of_prod_purchas2  Nbr_of_prod_purchas3  \
# ID
# 85517                   1.0                   NaN                   NaN
# 51113                   1.0                   NaN                   NaN
# 83008                   1.0                   NaN                   NaN
# 78712                   1.0                   1.0                   NaN
# 77846                   1.0                   NaN                   NaN
#
#        Nbr_of_prod_purchas4  Nbr_of_prod_purchas5  Nbr_of_prod_purchas6  \
# ID
# 85517                   NaN                   NaN                   NaN
# 51113                   NaN                   NaN                   NaN
# 83008                   NaN                   NaN                   NaN
# 78712                   NaN                   NaN                   NaN
# 77846                   NaN                   NaN                   NaN
#
#        Nbr_of_prod_purchas7  Nbr_of_prod_purchas8  Nbr_of_prod_purchas9  \
# ID
# 85517                   NaN                   NaN                   NaN
# 51113                   NaN                   NaN                   NaN
# 83008                   NaN                   NaN                   NaN
# 78712                   NaN                   NaN                   NaN
# 77846                   NaN                   NaN                   NaN
#
#        Nbr_of_prod_purchas10  Nbr_of_prod_purchas11  Nbr_of_prod_purchas12  \
# ID
# 85517                    NaN                    NaN                    NaN
# 51113                    NaN                    NaN                    NaN
# 83008                    NaN                    NaN                    NaN
# 78712                    NaN                    NaN                    NaN
# 77846                    NaN                    NaN                    NaN
#
#        Nbr_of_prod_purchas13  Nbr_of_prod_purchas14  Nbr_of_prod_purchas15  \
# ID
# 85517                    NaN                    NaN                    NaN
# 51113                    NaN                    NaN                    NaN
# 83008                    NaN                    NaN                    NaN
# 78712                    NaN                    NaN                    NaN
# 77846                    NaN                    NaN                    NaN
#
#        Nbr_of_prod_purchas16  Nbr_of_prod_purchas17  Nbr_of_prod_purchas18  \
# ID
# 85517                    NaN                    NaN                    NaN
# 51113                    NaN                    NaN                    NaN
# 83008                    NaN                    NaN                    NaN
# 78712                    NaN                    NaN                    NaN
# 77846                    NaN                    NaN                    NaN
#
#        Nbr_of_prod_purchas19  Nbr_of_prod_purchas20  Nbr_of_prod_purchas21  \
# ID
# 85517                    NaN                    NaN                    NaN
# 51113                    NaN                    NaN                    NaN
# 83008                    NaN                    NaN                    NaN
# 78712                    NaN                    NaN                    NaN
# 77846                    NaN                    NaN                    NaN
#
#        Nbr_of_prod_purchas22  Nbr_of_prod_purchas23  Nbr_of_prod_purchas24  \
# ID
# 85517                    NaN                    NaN                    NaN
# 51113                    NaN                    NaN                    NaN
# 83008                    NaN                    NaN                    NaN
# 78712                    NaN                    NaN                    NaN
# 77846                    NaN                    NaN                    NaN
#
#        Nb_of_items
# ID
# 85517          1.0
# 51113          1.0
# 83008          1.0
# 78712          2.0
# 77846          1.0

# %%
for i in range(1,25):
    xtrain_copy[f'item{i}']=xtrain_copy[f'item{i}'].fillna("")
    
    
xtrain_copy['item']=xtrain_copy['item1']
for i in range(2,25):
    xtrain_copy['item'] = xtrain_copy['item'] + " " + xtrain_copy[f'item{i}']
    
for i in range(1,25):
    xtrain_copy=xtrain_copy.drop([f'item{i}'],axis=1)

# %%
for i in range(1,25):
    
    xtrain_copy[f'cash_price{i}'] = xtrain_copy[f'cash_price{i}'].fillna(0)
    
xtrain_copy['cash_price']=xtrain_copy['cash_price1']
for i in range(2,25):
    xtrain_copy['cash_price'] = xtrain_copy['cash_price'] + xtrain_copy[f'cash_price{i}']

for i in range(1,25):
    xtrain_copy=xtrain_copy.drop([f'cash_price{i}'],axis=1)

# %%
for i in range(1,25):
    
    xtrain_copy[f'make{i}'] = xtrain_copy[f'make{i}'].fillna("")

xtrain_copy['make']=xtrain_copy['make1']
for i in range(2,25):
    xtrain_copy['make'] = xtrain_copy['make'] + " " + xtrain_copy[f'make{i}']

for i in range(1,25):
    xtrain_copy=xtrain_copy.drop([f'make{i}'],axis=1)

# %%
for i in range(1,25):
    
    xtrain_copy[f'model{i}'] = xtrain_copy[f'model{i}'].fillna("")
xtrain_copy['model']=xtrain_copy['model1']
for i in range(2,25):
    xtrain_copy['model'] = xtrain_copy['model'] + " " + xtrain_copy[f'model{i}']

for i in range(1,25):
    xtrain_copy=xtrain_copy.drop([f'model{i}'],axis=1)

# %%
for i in range(1,25):
    xtrain_copy=xtrain_copy.drop([f'goods_code{i}'],axis=1)
    xtrain_copy=xtrain_copy.drop([f'Nbr_of_prod_purchas{i}'],axis=1)

# %%
xtrain_copy.head()
# Out:
#        Nb_of_items                                               item  \
# ID
# 85517          1.0                   COMPUTERS
# 51113          1.0  COMPUTER PERIPHERALS ACCESSORIES              ...
# 83008          1.0     TELEVISIONS HOME CINEMA
# 78712          2.0  COMPUTERS COMPUTER PERIPHERALS ACCESSORIES    ...
# 77846          1.0     TELEVISIONS HOME CINEMA
#
#        cash_price                               make  \
# ID
# 85517       889.0       APPLE
# 51113       409.0       APPLE
# 83008      1399.0     SAMSUNG
# 78712       808.0  APPLE APPLE
# 77846      1199.0        SONY
#
#                                                    model
# ID
# 85517  2020 APPLE MACBOOK AIR 13 3 RETINA DISPLAY M1 ...
# 51113  APPLE WATCH SERIES 6 GPS 44MM SPACE GREY ALUMI...
# 83008  SAMSUNG QE75Q70A 2021 QLED HDR 4K ULTRA HD SMA...
# 78712  2020 APPLE IPAD AIR 10 9 A14 BIONIC PROCESSOR ...
# 77846  SONY BRAVIA KE48A9 2020 OLED HDR 4K ULTRA HD S...

# %%
data=xtrain_copy.copy()

# %%
nbrListe  = [1, 2, 3, 3, 2, 4, 5]
new_list = [] 
for i in nbrListe : 
    if i not in new_list: 
        new_list.append(i) 
print(new_list)

# %%
data['item'][0]
# Out:
# ['COMPUTERS', 'WARRANTY', 'FULFILMENT', 'CHARGE']

# %%
# Supprimer les doublons et espaces

for i in range(data.shape[0]):
    
    resultantList = []
    for element in (data['item'][i].split()):
        if element not in resultantList:
            resultantList.append(element)
    data['item'][i] = resultantList
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_11456\2091822257.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['item'][i] = resultantList
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 3
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11456\2091822257.py in <module>
#       4
#       5     resultantList = []
# ----> 6     for element in (data['item'][i].split()):
#       7         if element not in resultantList:
#       8             resultantList.append(element)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     956
#     957         elif key_is_scalar:
# --> 958             return self._get_value(key)
#     959
#     960         if is_hashable(key):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in _get_value(self, label, takeable)
#    1067
#    1068         # Similar to Index.get_value, but we do not fall back to positional
# -> 1069         loc = self.index.get_loc(label)
#    1070         return self.index._get_values_for_loc(self, loc, label)
#    1071
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
# -> 3631                 raise KeyError(key) from err
#    3632             except TypeError:
#    3633                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 3

# %%
# convert list to chaine

for i in range(data.shape[0]):

    mystring = ''
    for x in data['item'][i]:
        mystring += ''+ x
    data['item'][i] = mystring

# %%
# Supprimer les doublons et espaces

for i in range(data.shape[0]):
    
    resultantList = []
    for element in (data['make'][i].split()):
        if element not in resultantList:
            resultantList.append(element)
    data['make'][i] = resultantList
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_11456\1052069911.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['make'][i] = resultantList
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 3
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11456\1052069911.py in <module>
#       4
#       5     resultantList = []
# ----> 6     for element in (data['make'][i].split()):
#       7         if element not in resultantList:
#       8             resultantList.append(element)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     956
#     957         elif key_is_scalar:
# --> 958             return self._get_value(key)
#     959
#     960         if is_hashable(key):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in _get_value(self, label, takeable)
#    1067
#    1068         # Similar to Index.get_value, but we do not fall back to positional
# -> 1069         loc = self.index.get_loc(label)
#    1070         return self.index._get_values_for_loc(self, loc, label)
#    1071
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
# -> 3631                 raise KeyError(key) from err
#    3632             except TypeError:
#    3633                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 3

# %%
# convert list to chaine


for i in range(data.shape[0]):

    mystring = ''
    for x in data['make'][i]:
        mystring += ''+ x
    data['make'][i] = mystring

# %%
# Supprimer les doublons et espaces

for i in range(data.shape[0]):
    
    resultantList = []
    for element in (data['model'][i].split()):
        if element not in resultantList:
            resultantList.append(element)
    data['model'][i] = resultantList

# %%
# convert list to chaine
for i in range(data.shape[0]):

    mystring = ''
    for x in data['model'][i]:
        mystring += ''+ x
    data['model'][i] = mystring

# %%
data.head()

# %% [markdown]
# # data processing

# %%
from sklearn import preprocessing

number = preprocessing.LabelEncoder()
#number = preprocessing.OneHotEncoder()

data['make'] = number.fit_transform(data.make)
data['item'] = number.fit_transform(data.item)
data['model'] = number.fit_transform(data.model)

# %%
data.to_csv('pre_process_xtrain.csv')
