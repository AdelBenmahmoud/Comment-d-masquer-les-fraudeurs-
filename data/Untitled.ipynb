# %%
import pandas as pd

# %%
X_train = pd.read_csv('X_train_G3tdtEn.csv',low_memory=False, index_col=0)
y_train = pd.read_csv('Y_train_2_XPXJDyy.csv',low_memory=False, index_col=0)

X_test = pd.read_csv('X_train_G3tdtEn.csv',low_memory=False, index_col=0)
y_test = pd.read_csv('Y_test_random_2.csv',low_memory=False, index_col=0)

# %%
X_train.head(2)
# Out:
#                                   item1 item2 item3 item4 item5 item6 item7  \
# ID
# 85517                         COMPUTERS   NaN   NaN   NaN   NaN   NaN   NaN
# 51113  COMPUTER PERIPHERALS ACCESSORIES   NaN   NaN   NaN   NaN   NaN   NaN
#
#       item8 item9 item10  ... Nbr_of_prod_purchas16 Nbr_of_prod_purchas17  \
# ID                        ...
# 85517   NaN   NaN    NaN  ...                   NaN                   NaN
# 51113   NaN   NaN    NaN  ...                   NaN                   NaN
#
#       Nbr_of_prod_purchas18 Nbr_of_prod_purchas19 Nbr_of_prod_purchas20  \
# ID
# 85517                   NaN                   NaN                   NaN
# 51113                   NaN                   NaN                   NaN
#
#       Nbr_of_prod_purchas21 Nbr_of_prod_purchas22 Nbr_of_prod_purchas23  \
# ID
# 85517                   NaN                   NaN                   NaN
# 51113                   NaN                   NaN                   NaN
#
# ...

# %%
y_train.head(2)
# Out:
#           ID  fraud_flag
# index
# 0      85517           0
# 1      51113           0

# %%
X_test.head(2)
# Out:
#                                   item1 item2 item3 item4 item5 item6 item7  \
# ID
# 85517                         COMPUTERS   NaN   NaN   NaN   NaN   NaN   NaN
# 51113  COMPUTER PERIPHERALS ACCESSORIES   NaN   NaN   NaN   NaN   NaN   NaN
#
#       item8 item9 item10  ... Nbr_of_prod_purchas16 Nbr_of_prod_purchas17  \
# ID                        ...
# 85517   NaN   NaN    NaN  ...                   NaN                   NaN
# 51113   NaN   NaN    NaN  ...                   NaN                   NaN
#
#       Nbr_of_prod_purchas18 Nbr_of_prod_purchas19 Nbr_of_prod_purchas20  \
# ID
# 85517                   NaN                   NaN                   NaN
# 51113                   NaN                   NaN                   NaN
#
#       Nbr_of_prod_purchas21 Nbr_of_prod_purchas22 Nbr_of_prod_purchas23  \
# ID
# 85517                   NaN                   NaN                   NaN
# 51113                   NaN                   NaN                   NaN
#
# ...

# %%
y_test.head(2)
# Out:
#           ID  fraud_flag
# index
# 0      64707    0.165105
# 1      63919    0.284590

# %%
import numpy as np
from sklearn.metrics import average_precision_score
y_true = np.array([0.5, 0.84, 0.35, 0.68])
y_scores = np.array([0.1, 0.4, 0.35, 0.8])
average_precision_score(y_true, y_scores)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6076\3491221184.py in <module>
#       3 y_true = np.array([0.5, 0.84, 0.35, 0.68])
#       4 y_scores = np.array([0.1, 0.4, 0.35, 0.8])
# ----> 5 average_precision_score(y_true, y_scores)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_ranking.py in average_precision_score(y_true, y_score, average, pos_label, sample_weight)
#     230         _binary_uninterpolated_average_precision, pos_label=pos_label
#     231     )
# --> 232     return _average_binary_score(
#     233         average_precision, y_true, y_score, average, sample_weight=sample_weight
#     234     )
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_base.py in _average_binary_score(binary_metric, y_true, y_score, average, sample_weight)
#      70     y_type = type_of_target(y_true)
# ...

# %%
y_true.dtype
# Out:
# dtype('int32')
